# %% [markdown]
# <a href="https://colab.research.google.com/github/aiswaryajoseph2004-bot/EDA/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/diamonds.csv")
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
df=data

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50000 non-null  float64
#  1   cut      50000 non-null  object
#  2   color    50000 non-null  object
#  3   clarity  50000 non-null  object
#  4   depth    50000 non-null  float64
#  5   table    50000 non-null  float64
#  6   price    50000 non-null  int64
#  7   x        50000 non-null  float64
#  8   y        50000 non-null  float64
#  9   z        50000 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.8+ MB

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
print(df['cut'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        19938
# Premium      12806
# Very Good    11204
# Good          4557
# Fair          1495
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.shape
# Out:
# (50000, 10)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (49874, 10)

# %%
plt.hist(df['price'])
plt.show()

# %%
sns.histplot(df['depth'], kde=True)
plt.show()

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49874 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    49874 non-null  float64
#  1   cut      49874 non-null  object
#  2   color    49874 non-null  object
#  3   clarity  49874 non-null  object
#  4   depth    49874 non-null  float64
#  5   table    49874 non-null  float64
#  6   price    49874 non-null  int64
#  7   x        49874 non-null  float64
#  8   y        49874 non-null  float64
#  9   z        49874 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.2+ MB

# %%
df["cut"].replace(["fair","Good","Very Good","Premium",'Ideal'],[1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipython-input-1685010730.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cut"].replace(["fair","Good","Very Good","Premium",'Ideal'],[1,2,3,4,5],inplace=True)

# %%
df
# Out:
#        carat cut color clarity  depth  table  price     x     y     z
# 0       0.23   5     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   4     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   2     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   4     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   2     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ..   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72   5     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72   2     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70   3     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86   4     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75   5     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(df['color'].unique())
# Out:
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']

# %%
df["color"].replace(['J','I','H','F','E','D'],[1,2,3,4,5,6],inplace=True)
# Out:
# /tmp/ipython-input-1999224097.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["color"].replace(['J','I','H','F','E','D'],[1,2,3,4,5,6],inplace=True)

# %%
df
# Out:
#        carat cut color clarity  depth  table  price     x     y     z
# 0       0.23   5     5     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   4     5     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   2     5     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   4     2     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   2     1     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ..   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72   5     6     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72   2     6     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70   3     6     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86   4     3     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75   5     6     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(df['clarity'].unique())
# Out:
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
df["clarity"].replace(['I1','SI2','SI1','VS2','VS1','WS2','WS1','IF'],[1,2,3,4,5,6,7,8],inplace=True)
# Out:
# /tmp/ipython-input-3805798167.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["clarity"].replace(['I1','SI2','SI1','VS2','VS1','WS2','WS1','IF'],[1,2,3,4,5,6,7,8],inplace=True)

# %%
df
# Out:
#        carat cut color clarity  depth  table  price     x     y     z
# 0       0.23   5     5       2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   4     5       3   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   2     5       5   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   4     2       4   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   2     1       2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ..   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72   5     6       3   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72   2     6       3   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70   3     6       3   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86   4     3       2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75   5     6       2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49874 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    49874 non-null  float64
#  1   cut      49874 non-null  object
#  2   color    49874 non-null  object
#  3   clarity  49874 non-null  object
#  4   depth    49874 non-null  float64
#  5   table    49874 non-null  float64
#  6   price    49874 non-null  int64
#  7   x        49874 non-null  float64
#  8   y        49874 non-null  float64
#  9   z        49874 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.2+ MB

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix,annot=True, fmt='0.01f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3949890089.py in <cell line: 0>()
# ----> 1 corr_matrix = df.corr()
#       2 sns.heatmap(corr_matrix,annot=True, fmt='0.01f', cmap='coolwarm')
#       3 plt.title('Correlation Matrix')
#       4 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
x=df[['carat']]#independent variable
x
# Out:
#        carat
# 0       0.23
# 1       0.21
# 2       0.23
# 3       0.29
# 4       0.31
# ...      ...
# 49995   0.72
# 49996   0.72
# 49997   0.70
# 49998   0.86
# 49999   0.75
#
# [49874 rows x 1 columns]

# %%
y=df['price']#dependent
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 49995    2757
# 49996    2757
# 49997    2757
# 49998    2757
# 49999    2757
# Name: price, Length: 49874, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.8496778242384597

# %%
model.predict([[0.23]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-474.24425985])

# %%
df.drop(['x','y','z','carat'],axis=1,inplace=True)

# %%
df["color"] = df["color"].replace({'J':1, 'I':2, 'H':3, 'G':4, 'F':5, 'E':6, 'D':7})


df["clarity"] = df["clarity"].replace({'I1':1, 'SI2':2, 'SI1':3, 'VS2':4, 'VS1':5, 'VVS2':6, 'VVS1':7, 'IF':8})

price_corr = df.corr()['price']
price_corr = price_corr.drop('price')

sns.heatmap(price_corr.to_frame(), annot=True, fmt='.2f', cmap='coolwarm',
            cbar=True, annot_kws={'size': 10})
plt.title('Correlation between price and Other Features')
plt.show()
# Out:
# /tmp/ipython-input-936247286.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["color"] = df["color"].replace({'J':1, 'I':2, 'H':3, 'G':4, 'F':5, 'E':6, 'D':7})
# /tmp/ipython-input-936247286.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["clarity"] = df["clarity"].replace({'I1':1, 'SI2':2, 'SI1':3, 'VS2':4, 'VS1':5, 'VVS2':6, 'VVS1':7, 'IF':8})

# %%
df.drop(['cut','depth'],axis=1,inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df, exclude_column):
    for col in df.columns:
        if col == exclude_column:
            continue
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df
df_cleaned = remove_outliers_iqr(df, exclude_column='price')
df=df_cleaned
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-152152471.py in <cell line: 0>()
#      10         df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
#      11     return df
# ---> 12 df_cleaned = remove_outliers_iqr(df, exclude_column='price')
#      13 df=df_cleaned
#
# /tmp/ipython-input-152152471.py in remove_outliers_iqr(df, exclude_column)
#       3         if col == exclude_column:
#       4             continue
# ----> 5         Q1 = df[col].quantile(0.25)
#       6         Q3 = df[col].quantile(0.75)
#       7         IQR = Q3 - Q1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    2885         df = self.to_frame()
#    2886
# -> 2887         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888         if result.ndim == 2:
# ...

# %%
df.shape

# %%
df

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
features = ['color','clarity','table','price']
scaler = MinMaxScaler()
scaled_data= scaler.fit_transform(df[features])
scaled_df = pd.DataFrame(scaled_data, columns=features)
